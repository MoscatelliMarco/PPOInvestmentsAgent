# %%
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %%
# Fetch AAPL stock data
df = yf.download('EURUSD=X', start='2018-01-01', end='2023-12-01', interval='1d')

# Extract closing prices and dates
closing_prices = df['Close'].values
dates = np.arange(len(closing_prices))  # Using integers for dates for simplicity
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# Perform a polynomial fit (degree 3 for example)
degree = 4
coefficients = np.polyfit(dates, closing_prices, degree)
polynomial = np.poly1d(coefficients)

# Generate polynomial line
poly_line = polynomial(dates)

# %%
# Plotting
plt.figure(figsize=(10, 5))
plt.plot(df.index, closing_prices, label='Actual Closing Prices')
plt.plot(df.index, poly_line, label='Polynomial Fit', color='red')
plt.title('Polynomial Fit of AAPL Stock Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
